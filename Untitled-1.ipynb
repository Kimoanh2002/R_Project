# %%
import pandas as pd

# %%
df = pd.read_csv("data_processed.csv", sep=',')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction.Score Card.Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
test_data = df[df['RowNumber'] > 9700]
test_data.head()
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 9335       9701    15797149     Lloyd          563     Spain  Female   36
# 9336       9702    15636912   Sneddon          678     Spain    Male   38
# 9337       9703    15687828  Gorshkov          644     Spain  Female   31
# 9338       9704    15667424    Forbes          682   Germany  Female   43
# 9339       9705    15759872        L?          625    France    Male   22
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9335       4  143680.47              2          1               1
# 9336       3  124483.53              1          1               0
# 9337       5   86006.30              1          1               1
# 9338       7  111094.05              2          1               1
# 9339       9       0.00              2          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction.Score Card.Type  \
# ...

# %%
test_data.describe()
# Out:
#           RowNumber    CustomerId  CreditScore         Age      Tenure  \
# count    291.000000  2.910000e+02   291.000000  291.000000  291.000000
# mean    9852.271478  1.569201e+07   656.958763   37.295533    5.243986
# std       86.553542  7.465306e+04    92.966466    8.600037    2.960474
# min     9701.000000  1.556654e+07   425.000000   18.000000    0.000000
# 25%     9779.500000  1.562290e+07   595.000000   31.000000    3.000000
# 50%     9853.000000  1.569117e+07   658.000000   37.000000    5.000000
# 75%     9926.500000  1.576274e+07   724.000000   42.000000    8.000000
# max    10000.000000  1.581510e+07   850.000000   62.000000   10.000000
#
#              Balance  NumOfProducts   HasCrCard  IsActiveMember  \
# count     291.000000     291.000000  291.000000      291.000000
# mean    82594.941168       1.477663    0.742268        0.549828
# std     61845.175298       0.533708    0.438139        0.498368
# min         0.000000       1.000000    0.000000        0.000000
# ...

# %%
test_data.to_csv("test_data.csv", header=True)
